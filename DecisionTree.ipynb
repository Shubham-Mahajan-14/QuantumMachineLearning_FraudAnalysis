# %%
import pandas as pd

df = pd.read_csv("customer_data.csv")

# %%
df['churn'] = (df['churn_probability'] > 0.25).astype(int)

# %%
df['churn'].value_counts()
# Out:
# churn
# 1    43368
# 0     5355
# Name: count, dtype: int64

# %%
df = df.drop(['customer_id', 'churn_probability'], axis=1)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
X = df.drop('churn', axis=1)
y = df['churn']

# %%
X = X.fillna(X.mean()) # imputation

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y, test_size=0.2, random_state=42
)

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1085
#            1       1.00      1.00      1.00      8660
#
#     accuracy                           1.00      9745
#    macro avg       1.00      1.00      1.00      9745
# weighted avg       1.00      1.00      1.00      9745

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report

dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      1085
#            1       1.00      1.00      1.00      8660
#
#     accuracy                           1.00      9745
#    macro avg       1.00      1.00      1.00      9745
# weighted avg       1.00      1.00      1.00      9745

# %%
dt.score(X_train, y_train)
dt.score(X_test, y_test)
# Out:
# 0.9987685992816829

# %%
from sklearn.tree import DecisionTreeClassifier

dt = DecisionTreeClassifier(
    max_depth=5,          # limit depth
    min_samples_split=10, # prevent overfitting
    min_samples_leaf=5
)

dt.fit(X_train, y_train)

y_pred_dt = dt.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.90      0.93      1085
#            1       0.99      0.99      0.99      8660
#
#     accuracy                           0.98      9745
#    macro avg       0.97      0.95      0.96      9745
# weighted avg       0.98      0.98      0.98      9745

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      1085
#            1       0.89      1.00      0.94      8660
#
#     accuracy                           0.89      9745
#    macro avg       0.44      0.50      0.47      9745
# weighted avg       0.79      0.89      0.84      9745
# C:\Users\Shubham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Shubham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\Shubham\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    class_weight='balanced',  
    random_state=42
)

rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.73      0.92      0.82      1085
#            1       0.99      0.96      0.97      8660
#
#     accuracy                           0.95      9745
#    macro avg       0.86      0.94      0.90      9745
# weighted avg       0.96      0.95      0.96      9745
